# %% [markdown]
# # 03 - Severity Model
# - Load features.csv
# - Train SeverityClassifier
# - Print classification report
# - SHAP summary plot (beeswarm)
# - SHAP waterfall for one Critical example and one Low example
# - Feature importance bar chart
