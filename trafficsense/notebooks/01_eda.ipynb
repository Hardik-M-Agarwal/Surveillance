# %% [markdown]
# # 01 - Exploratory Data Analysis
# 1. Load raw data, show shape and dtypes
# 2. Missing value heatmap (seaborn)
# 3. event_cause distribution (bar chart)
# 4. corridor distribution (top 20, bar chart)
# 5. Hourly incident frequency — highlight peaks at 4–6 AM and 19–22h
# 6. Day-of-week distribution
# 7. requires_road_closure rate by event_cause (sorted bar)
# 8. Duration distribution (log scale histogram, filter out >5000 min)
# 9. severity label distribution after engineering
# 10. Correlation heatmap of numeric features
# 11. Geo scatter plot of incidents using lat/lon colored by severity (using plotly)
# 12. Key takeaways cell (markdown)
