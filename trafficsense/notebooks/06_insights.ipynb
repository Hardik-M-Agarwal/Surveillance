# %% [markdown]
# # 06 - Insights
# - Final polished versions of all 6 charts from Page 3
# - All charts must be publication-ready (proper titles, axis labels, color legends)
# - End with a 'Hackathon pitch summary' markdown cell
